# %%
import pandas as pd
import numpy as np
import plotly.express as px
import os

# %%
os.chdir('E:\CDSP\Mid_Project')

# %%
df = pd.read_excel('E:\CDSP\Marketing_product_performance.xlsx')
df
# Out:
#       Campaign_ID   Product_ID    Budget  Clicks  Conversions  \
# 0      CMP_RLSDVN  PROD_HBJFA3  41770.45  4946.0           73
# 1      CMP_JHHUE9  PROD_OE8YNJ  29900.93   570.0          510
# 2      CMP_6SBOWN  PROD_4V8A08  22367.45  3546.0          265
# 3      CMP_Q31QCU  PROD_A1Q6ZB  29957.54  2573.0          781
# 4      CMP_AY0UTJ  PROD_F57N66  36277.19   818.0           79
# ...           ...          ...       ...     ...          ...
# 10056  CMP_U1BQY9  PROD_F204EM       NaN    25.0          720
# 10057  CMP_ZQDI7T  PROD_5313XR       NaN  3503.0          799
# 10058  CMP_SYFTKH  PROD_44T74P       NaN  1140.0          428
# 10059  CMP_FTAW8H  PROD_CPN4QT       NaN  1078.0          409
# 10060  CMP_3L1U09  PROD_W5MSRO       NaN  1682.0          935
#
#        Revenue_Generated   ROI  Customer_ID Subscription_Tier  \
# 0             159835.710  1.94  CUST_1K7G39           Premium
# 1             165074.115  0.76  CUST_0DWS6F           Premium
# 2             124053.975  1.41  CUST_BR2GST             Basic
# 3             114789.652  3.32  CUST_6TBY6K           Premium
# 4             138472.322  3.53  CUST_XASI45          Standard
# ...                  ...   ...          ...               ...
# 10056         187627.666  4.61  CUST_K3F0GA           Premium
# 10057         146776.442  3.31  CUST_SY9H51          Standard
# 10058          82807.096  5.00  CUST_C6LMF4          Standard
# 10059         136524.852  4.08  CUST_URFVAQ             Basic
# 10060          28909.822  1.74  CUST_25UP1Z           Premium
#
#        Subscription_Length Flash_Sale_ID  Discount_Level  Units_Sold  \
# 0                        4  FLASH_1VFK5K            0.43          34
# 1                        4  FLASH_1M6COK            0.28          97
# 2                        9  FLASH_J4PEON            0.51         160
# 3                       32  FLASH_1TOVXT            0.36         159
# 4                       29  FLASH_AOBHXL            0.20          52
# ...                    ...           ...             ...         ...
# 10056                   18  FLASH_WOTOXI            0.25          95
# 10057                   18  FLASH_3HIKX0            0.10           5
# 10058                   19  FLASH_W3KMY9            0.37         191
# 10059                   31  FLASH_L4UDXZ            0.59          73
# 10060                    3  FLASH_ZGYPFO            0.68           4
#
#          Bundle_ID  Bundle_Price  Customer_Satisfaction_Post_Refund  \
# 0      BNDL_29U6W5        433.80                                  4
# 1      BNDL_ULV60J        289.29                                  2
# 2      BNDL_0HY0EF        462.87                                  4
# 3      BNDL_AI09BC        334.16                                  1
# 4      BNDL_R03ITT        371.67                                  2
# ...            ...           ...                                ...
# 10056  BNDL_6DN251           NaN                                  3
# 10057  BNDL_24U1RG           NaN                                  2
# 10058  BNDL_MIA2QO           NaN                                  3
# 10059  BNDL_PHIE38           NaN                                  4
# 10060  BNDL_H5CC7E           NaN                                  3
#
#       Kênh Marketing
# 0           Facebook
# 1             TikTok
# 2             TikTok
# 3             Google
# 4           Facebook
# ...              ...
# 10056         Google
# 10057         Google
# 10058       Facebook
# 10059       Facebook
# 10060         Google
#
# [10061 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10061 entries, 0 to 10060
# Data columns (total 17 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Campaign_ID                        10061 non-null  object
#  1   Product_ID                         10061 non-null  object
#  2   Budget                             10033 non-null  float64
#  3   Clicks                             10041 non-null  float64
#  4   Conversions                        10061 non-null  int64
#  5   Revenue_Generated                  10051 non-null  float64
#  6   ROI                                10061 non-null  float64
#  7   Customer_ID                        10061 non-null  object
#  8   Subscription_Tier                  10061 non-null  object
#  9   Subscription_Length                10061 non-null  int64
#  10  Flash_Sale_ID                      10061 non-null  object
#  11  Discount_Level                     10061 non-null  float64
#  12  Units_Sold                         10061 non-null  int64
#  13  Bundle_ID                          10061 non-null  object
#  14  Bundle_Price                       10023 non-null  float64
#  15  Customer_Satisfaction_Post_Refund  10061 non-null  int64
#  16  Kênh Marketing                     10061 non-null  object
# dtypes: float64(6), int64(4), object(7)
# memory usage: 1.3+ MB

# %%
df.isna().mean()*100
# Out:
# Campaign_ID                          0.000000
# Product_ID                           0.000000
# Budget                               0.278302
# Clicks                               0.198787
# Conversions                          0.000000
# Revenue_Generated                    0.099394
# ROI                                  0.000000
# Customer_ID                          0.000000
# Subscription_Tier                    0.000000
# Subscription_Length                  0.000000
# Flash_Sale_ID                        0.000000
# Discount_Level                       0.000000
# Units_Sold                           0.000000
# Bundle_ID                            0.000000
# Bundle_Price                         0.377696
# Customer_Satisfaction_Post_Refund    0.000000
# Kênh Marketing                       0.000000
# dtype: float64

# %%
cols_to_fill = [
    'Budget',
    'Clicks',
    'Revenue_Generated',
    'Bundle_Price'
]

for col in cols_to_fill:
    df[col] = df[col].fillna(df[col].median())

# %%
df.isna().mean()*100
# Out:
# Campaign_ID                          0.0
# Product_ID                           0.0
# Budget                               0.0
# Clicks                               0.0
# Conversions                          0.0
# Revenue_Generated                    0.0
# ROI                                  0.0
# Customer_ID                          0.0
# Subscription_Tier                    0.0
# Subscription_Length                  0.0
# Flash_Sale_ID                        0.0
# Discount_Level                       0.0
# Units_Sold                           0.0
# Bundle_ID                            0.0
# Bundle_Price                         0.0
# Customer_Satisfaction_Post_Refund    0.0
# Kênh Marketing                       0.0
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(61)

# %%
df.drop_duplicates(inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 0 to 10060
# Data columns (total 17 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Campaign_ID                        10000 non-null  object
#  1   Product_ID                         10000 non-null  object
#  2   Budget                             10000 non-null  float64
#  3   Clicks                             10000 non-null  float64
#  4   Conversions                        10000 non-null  int64
#  5   Revenue_Generated                  10000 non-null  float64
#  6   ROI                                10000 non-null  float64
#  7   Customer_ID                        10000 non-null  object
#  8   Subscription_Tier                  10000 non-null  object
#  9   Subscription_Length                10000 non-null  int64
#  10  Flash_Sale_ID                      10000 non-null  object
#  11  Discount_Level                     10000 non-null  float64
#  12  Units_Sold                         10000 non-null  int64
#  13  Bundle_ID                          10000 non-null  object
#  14  Bundle_Price                       10000 non-null  float64
#  15  Customer_Satisfaction_Post_Refund  10000 non-null  int64
#  16  Kênh Marketing                     10000 non-null  object
# dtypes: float64(6), int64(4), object(7)
# memory usage: 1.4+ MB

# %%
df = df.rename(columns = {'Revenue_Generated':'Revenue Generated','Subscription_Length':'Subscription Length','Discount_Level': 'Discount Level','Units_Sold':'Units Sold','Bundle_Price':'Bundle Price','Customer_Satisfaction_Post_Refund':'Customer Satisfaction Post Refund'})

# %%
df.head()
# Out:
#   Campaign_ID   Product_ID    Budget  Clicks  Conversions  Revenue Generated  \
# 0  CMP_RLSDVN  PROD_HBJFA3  41770.45  4946.0           73         159835.710
# 1  CMP_JHHUE9  PROD_OE8YNJ  29900.93   570.0          510         165074.115
# 2  CMP_6SBOWN  PROD_4V8A08  22367.45  3546.0          265         124053.975
# 3  CMP_Q31QCU  PROD_A1Q6ZB  29957.54  2573.0          781         114789.652
# 4  CMP_AY0UTJ  PROD_F57N66  36277.19   818.0           79         138472.322
#
#     ROI  Customer_ID Subscription_Tier  Subscription Length Flash_Sale_ID  \
# 0  1.94  CUST_1K7G39           Premium                    4  FLASH_1VFK5K
# 1  0.76  CUST_0DWS6F           Premium                    4  FLASH_1M6COK
# 2  1.41  CUST_BR2GST             Basic                    9  FLASH_J4PEON
# 3  3.32  CUST_6TBY6K           Premium                   32  FLASH_1TOVXT
# 4  3.53  CUST_XASI45          Standard                   29  FLASH_AOBHXL
#
#    Discount Level  Units Sold    Bundle_ID  Bundle Price  \
# 0            0.43          34  BNDL_29U6W5        433.80
# 1            0.28          97  BNDL_ULV60J        289.29
# 2            0.51         160  BNDL_0HY0EF        462.87
# 3            0.36         159  BNDL_AI09BC        334.16
# 4            0.20          52  BNDL_R03ITT        371.67
#
#    Customer Satisfaction Post Refund Kênh Marketing
# 0                                  4       Facebook
# 1                                  2         TikTok
# 2                                  4         TikTok
# 3                                  1         Google
# 4                                  2       Facebook

# %%
numlst = df.select_dtypes(include='number').columns
for col in numlst:
    fig = px.box(data_frame = df, x = col)
    fig.show()

# %%
df.describe(include = 'number').round(2)
# Out:
#          Budget    Clicks  Conversions  Revenue Generated       ROI  \
# count  10000.00  10000.00     10000.00           10000.00  10000.00
# mean   25263.03   2480.84       498.98          122024.43      2.76
# std    14335.47   1435.15       289.48           74586.59      1.30
# min      500.44     10.00         1.00            2346.02      0.50
# 25%    12809.13   1226.00       247.00           60468.87      1.63
# 50%    25012.15   2450.00       499.00          116712.29      2.75
# 75%    37898.14   3721.00       751.00          173205.98      3.89
# max    49999.63   4999.00       999.00          305392.74      5.00
#
#        Subscription Length  Discount Level  Units Sold  Bundle Price  \
# count             10000.00        10000.00    10000.00      10000.00
# mean                 18.02            0.39      100.69        275.11
# std                  10.15            0.17       57.07        129.11
# min                   1.00            0.10        1.00         50.01
# 25%                   9.00            0.24       52.00        165.74
# 50%                  18.00            0.39      101.00        271.86
# 75%                  27.00            0.54      150.00        387.08
# max                  35.00            0.69      199.00        499.97
#
#        Customer Satisfaction Post Refund
# count                           10000.00
# mean                                2.50
# std                                 1.11
# min                                 1.00
# 25%                                 2.00
# 50%                                 2.00
# 75%                                 3.00
# max                                 4.00

# %%
df.describe(include= 'object')
# Out:
#        Campaign_ID   Product_ID  Customer_ID Subscription_Tier Flash_Sale_ID  \
# count        10000        10000        10000             10000         10000
# unique       10000        10000        10000                 3         10000
# top     CMP_RLSDVN  PROD_HBJFA3  CUST_1K7G39             Basic  FLASH_1VFK5K
# freq             1            1            1              3416             1
#
#           Bundle_ID Kênh Marketing
# count         10000          10000
# unique        10000              4
# top     BNDL_29U6W5       Facebook
# freq              1           2564

# %%
df = df.rename(columns = {'Kênh Marketing':'Marketing Channels'})
df
# Out:
#       Campaign_ID   Product_ID    Budget  Clicks  Conversions  \
# 0      CMP_RLSDVN  PROD_HBJFA3  41770.45  4946.0           73
# 1      CMP_JHHUE9  PROD_OE8YNJ  29900.93   570.0          510
# 2      CMP_6SBOWN  PROD_4V8A08  22367.45  3546.0          265
# 3      CMP_Q31QCU  PROD_A1Q6ZB  29957.54  2573.0          781
# 4      CMP_AY0UTJ  PROD_F57N66  36277.19   818.0           79
# ...           ...          ...       ...     ...          ...
# 9995   CMP_U1BQY9  PROD_F204EM  25012.15    25.0          720
# 10057  CMP_ZQDI7T  PROD_5313XR  25012.15  3503.0          799
# 10058  CMP_SYFTKH  PROD_44T74P  25012.15  1140.0          428
# 10059  CMP_FTAW8H  PROD_CPN4QT  25012.15  1078.0          409
# 10060  CMP_3L1U09  PROD_W5MSRO  25012.15  1682.0          935
#
#        Revenue Generated   ROI  Customer_ID Subscription_Tier  \
# 0             159835.710  1.94  CUST_1K7G39           Premium
# 1             165074.115  0.76  CUST_0DWS6F           Premium
# 2             124053.975  1.41  CUST_BR2GST             Basic
# 3             114789.652  3.32  CUST_6TBY6K           Premium
# 4             138472.322  3.53  CUST_XASI45          Standard
# ...                  ...   ...          ...               ...
# 9995          187627.666  4.61  CUST_K3F0GA           Premium
# 10057         146776.442  3.31  CUST_SY9H51          Standard
# 10058          82807.096  5.00  CUST_C6LMF4          Standard
# 10059         136524.852  4.08  CUST_URFVAQ             Basic
# 10060          28909.822  1.74  CUST_25UP1Z           Premium
#
#        Subscription Length Flash_Sale_ID  Discount Level  Units Sold  \
# 0                        4  FLASH_1VFK5K            0.43          34
# 1                        4  FLASH_1M6COK            0.28          97
# 2                        9  FLASH_J4PEON            0.51         160
# 3                       32  FLASH_1TOVXT            0.36         159
# 4                       29  FLASH_AOBHXL            0.20          52
# ...                    ...           ...             ...         ...
# 9995                    18  FLASH_WOTOXI            0.25          95
# 10057                   18  FLASH_3HIKX0            0.10           5
# 10058                   19  FLASH_W3KMY9            0.37         191
# 10059                   31  FLASH_L4UDXZ            0.59          73
# 10060                    3  FLASH_ZGYPFO            0.68           4
#
#          Bundle_ID  Bundle Price  Customer Satisfaction Post Refund  \
# 0      BNDL_29U6W5        433.80                                  4
# 1      BNDL_ULV60J        289.29                                  2
# 2      BNDL_0HY0EF        462.87                                  4
# 3      BNDL_AI09BC        334.16                                  1
# 4      BNDL_R03ITT        371.67                                  2
# ...            ...           ...                                ...
# 9995   BNDL_6DN251        271.86                                  3
# 10057  BNDL_24U1RG        271.86                                  2
# 10058  BNDL_MIA2QO        271.86                                  3
# 10059  BNDL_PHIE38        271.86                                  4
# 10060  BNDL_H5CC7E        271.86                                  3
#
#       Marketing Channels
# 0               Facebook
# 1                 TikTok
# 2                 TikTok
# 3                 Google
# 4               Facebook
# ...                  ...
# 9995              Google
# 10057             Google
# 10058           Facebook
# 10059           Facebook
# 10060             Google
#
# [10000 rows x 17 columns]

# %%
cat_cols = df.select_dtypes(include= 'object').columns
for col in cat_cols:
    print(col)
    print(df[col].nunique())
    print(df[col].unique())
    print('-' * 100)
# Out:
# Campaign_ID
# 10000
# ['CMP_RLSDVN' 'CMP_JHHUE9' 'CMP_6SBOWN' ... 'CMP_SYFTKH' 'CMP_FTAW8H'
#  'CMP_3L1U09']
# ----------------------------------------------------------------------------------------------------
# Product_ID
# 10000
# ['PROD_HBJFA3' 'PROD_OE8YNJ' 'PROD_4V8A08' ... 'PROD_44T74P' 'PROD_CPN4QT'
#  'PROD_W5MSRO']
# ----------------------------------------------------------------------------------------------------
# Customer_ID
# 10000
# ['CUST_1K7G39' 'CUST_0DWS6F' 'CUST_BR2GST' ... 'CUST_C6LMF4' 'CUST_URFVAQ'
#  'CUST_25UP1Z']
# ----------------------------------------------------------------------------------------------------
# Subscription_Tier
# 3
# ['Premium' 'Basic' 'Standard']
# ----------------------------------------------------------------------------------------------------
# Flash_Sale_ID
# 10000
# ['FLASH_1VFK5K' 'FLASH_1M6COK' 'FLASH_J4PEON' ... 'FLASH_W3KMY9'
#  'FLASH_L4UDXZ' 'FLASH_ZGYPFO']
# ----------------------------------------------------------------------------------------------------
# Bundle_ID
# 10000
# ['BNDL_29U6W5' 'BNDL_ULV60J' 'BNDL_0HY0EF' ... 'BNDL_MIA2QO' 'BNDL_PHIE38'
#  'BNDL_H5CC7E']
# ----------------------------------------------------------------------------------------------------
# Marketing Channels
# 4
# ['Facebook' 'TikTok' 'Google' 'Affiliate']
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Feature Engneering

# %%
df['Conversion Rate'] = (df['Conversions'] / df['Clicks']) * 100
df['Budget per Conversion'] = df['Budget'] / df['Conversions']
df['Revenue Per Click'] = df['Revenue Generated'] / df['Clicks']
df['Revenue Per Unit'] = (df['Revenue Generated'] / df['Units Sold'])

# %%
df.head()
# Out:
#   Campaign_ID   Product_ID    Budget  Clicks  Conversions  Revenue Generated  \
# 0  CMP_RLSDVN  PROD_HBJFA3  41770.45  4946.0           73         159835.710
# 1  CMP_JHHUE9  PROD_OE8YNJ  29900.93   570.0          510         165074.115
# 2  CMP_6SBOWN  PROD_4V8A08  22367.45  3546.0          265         124053.975
# 3  CMP_Q31QCU  PROD_A1Q6ZB  29957.54  2573.0          781         114789.652
# 4  CMP_AY0UTJ  PROD_F57N66  36277.19   818.0           79         138472.322
#
#     ROI  Customer_ID Subscription_Tier  Subscription Length  ...  \
# 0  1.94  CUST_1K7G39           Premium                    4  ...
# 1  0.76  CUST_0DWS6F           Premium                    4  ...
# 2  1.41  CUST_BR2GST             Basic                    9  ...
# 3  3.32  CUST_6TBY6K           Premium                   32  ...
# 4  3.53  CUST_XASI45          Standard                   29  ...
#
#   Discount Level  Units Sold    Bundle_ID Bundle Price  \
# 0           0.43          34  BNDL_29U6W5       433.80
# 1           0.28          97  BNDL_ULV60J       289.29
# 2           0.51         160  BNDL_0HY0EF       462.87
# 3           0.36         159  BNDL_AI09BC       334.16
# 4           0.20          52  BNDL_R03ITT       371.67
#
#    Customer Satisfaction Post Refund  Marketing Channels Conversion Rate  \
# 0                                  4            Facebook        1.475940
# 1                                  2              TikTok       89.473684
# 2                                  4              TikTok        7.473209
# 3                                  1              Google       30.353673
# 4                                  2            Facebook        9.657702
#
#    Budget per Conversion  Revenue Per Click  Revenue Per Unit
# 0             572.197945          32.316156       4701.050294
# 1              58.629275         289.603711       1701.795000
# 2              84.405472          34.984201        775.337344
# 3              38.357926          44.613157        721.947497
# 4             459.204937         169.281567       2662.929269
#
# [5 rows x 21 columns]

# %%
df.to_excel('Cleaned Product Performance.xlsx')

# %% [markdown]
# # Data Analysis

# %%
# univariat analysis
px.pie(data_frame= df, names= 'Subscription_Tier')

# %%
catcol = ['Marketing Channels','Subscription_Tier']
for col in catcol:
    fig = px.histogram(data_frame= df, x= col, text_auto= True).update_xaxes(categoryorder = 'max descending')
    fig.show()

# %%
# bivariate
df_corr = df.corr(numeric_only= True).round(3)
df_corr
# Out:
#                                    Budget  Clicks  Conversions  \
# Budget                              1.000  -0.011       -0.017
# Clicks                             -0.011   1.000        0.008
# Conversions                        -0.017   0.008        1.000
# Revenue Generated                   0.918  -0.010       -0.010
# ROI                                 0.021   0.019       -0.009
# Subscription Length                -0.019   0.003        0.011
# Discount Level                     -0.005   0.011       -0.014
# Units Sold                          0.015   0.016        0.019
# Bundle Price                       -0.002   0.005       -0.026
# Customer Satisfaction Post Refund  -0.001  -0.003        0.002
# Conversion Rate                     0.011  -0.304        0.138
# Budget per Conversion               0.087   0.015       -0.216
# Revenue Per Click                   0.131  -0.283       -0.003
# Revenue Per Unit                    0.163  -0.006       -0.008
#
#                                    Revenue Generated    ROI  \
# Budget                                         0.918  0.021
# Clicks                                        -0.010  0.019
# Conversions                                   -0.010 -0.009
# Revenue Generated                              1.000  0.014
# ROI                                            0.014  1.000
# Subscription Length                           -0.015  0.009
# Discount Level                                 0.001  0.010
# Units Sold                                     0.018  0.009
# Bundle Price                                   0.000  0.015
# Customer Satisfaction Post Refund              0.004  0.000
# Conversion Rate                                0.018 -0.018
# Budget per Conversion                          0.073  0.019
# Revenue Per Click                              0.149 -0.011
# Revenue Per Unit                               0.172 -0.019
#
#                                    Subscription Length  Discount Level  \
# Budget                                          -0.019          -0.005
# Clicks                                           0.003           0.011
# Conversions                                      0.011          -0.014
# Revenue Generated                               -0.015           0.001
# ROI                                              0.009           0.010
# Subscription Length                              1.000          -0.004
# Discount Level                                  -0.004           1.000
# Units Sold                                       0.000           0.004
# Bundle Price                                     0.005           0.010
# Customer Satisfaction Post Refund               -0.007          -0.014
# Conversion Rate                                 -0.007          -0.014
# Budget per Conversion                           -0.010           0.013
# Revenue Per Click                               -0.007          -0.016
# Revenue Per Unit                                -0.003           0.004
#
#                                    Units Sold  Bundle Price  \
# Budget                                  0.015        -0.002
# Clicks                                  0.016         0.005
# Conversions                             0.019        -0.026
# Revenue Generated                       0.018         0.000
# ROI                                     0.009         0.015
# Subscription Length                     0.000         0.005
# Discount Level                          0.004         0.010
# Units Sold                              1.000        -0.001
# Bundle Price                           -0.001         1.000
# Customer Satisfaction Post Refund      -0.008        -0.007
# Conversion Rate                         0.004        -0.013
# Budget per Conversion                  -0.014         0.010
# Revenue Per Click                       0.002        -0.006
# Revenue Per Unit                       -0.335        -0.003
#
#                                    Customer Satisfaction Post Refund  \
# Budget                                                        -0.001
# Clicks                                                        -0.003
# Conversions                                                    0.002
# Revenue Generated                                              0.004
# ROI                                                            0.000
# Subscription Length                                           -0.007
# Discount Level                                                -0.014
# Units Sold                                                    -0.008
# Bundle Price                                                  -0.007
# Customer Satisfaction Post Refund                              1.000
# Conversion Rate                                               -0.012
# Budget per Conversion                                         -0.011
# Revenue Per Click                                             -0.001
# Revenue Per Unit                                               0.015
#
#                                    Conversion Rate  Budget per Conversion  \
# Budget                                       0.011                  0.087
# Clicks                                      -0.304                  0.015
# Conversions                                  0.138                 -0.216
# Revenue Generated                            0.018                  0.073
# ROI                                         -0.018                  0.019
# Subscription Length                         -0.007                 -0.010
# Discount Level                              -0.014                  0.013
# Units Sold                                   0.004                 -0.014
# Bundle Price                                -0.013                  0.010
# Customer Satisfaction Post Refund           -0.012                 -0.011
# Conversion Rate                              1.000                 -0.032
# Budget per Conversion                       -0.032                  1.000
# Revenue Per Click                            0.760                 -0.000
# Revenue Per Unit                             0.007                  0.020
#
#                                    Revenue Per Click  Revenue Per Unit
# Budget                                         0.131             0.163
# Clicks                                        -0.283            -0.006
# Conversions                                   -0.003            -0.008
# Revenue Generated                              0.149             0.172
# ROI                                           -0.011            -0.019
# Subscription Length                           -0.007            -0.003
# Discount Level                                -0.016             0.004
# Units Sold                                     0.002            -0.335
# Bundle Price                                  -0.006            -0.003
# Customer Satisfaction Post Refund             -0.001             0.015
# Conversion Rate                                0.760             0.007
# Budget per Conversion                         -0.000             0.020
# Revenue Per Click                              1.000             0.045
# Revenue Per Unit                               0.045             1.000

# %%
lst = [
    'Budget',
    'Clicks',
    'Conversions',
    'Revenue Generated',
    'Subscription Length',
    'Units Sold',
    'Bundle Price',
]

df_corrr = df[lst].corr().round(3)
px.imshow(df_corrr, text_auto= True)

# %%
# Which marketing channel generates the highest revenue 

plot1_df = df.groupby('Marketing Channels')['Revenue Generated'].sum().reset_index()
plot1_df['Revenue Generated'] = plot1_df['Revenue Generated'].round().astype(int)

px.bar(data_frame= plot1_df, x='Marketing Channels', y= 'Revenue Generated',text_auto= True,title = 'marketing channels per revenue ').update_xaxes(categoryorder = 'max descending')

# %%
month_sorted = df.sort_values('Subscription Length')

# %%
plot2_df = month_sorted.groupby('Subscription Length')['Customer_ID'].count().reset_index()

# %%
px.line(data_frame= plot2_df, x= 'Subscription Length', y= 'Customer_ID',
        labels= {'Subscription Length' : 'Month', 'Customer_ID' : 'Customer Count'},
        title= 'Total number of customers per month subscriptions',
        text= 'Customer_ID',
        line_shape= 'spline').update_traces(textposition= 'top center')

# %%
df.head()
# Out:
#   Campaign_ID   Product_ID    Budget  Clicks  Conversions  Revenue Generated  \
# 0  CMP_RLSDVN  PROD_HBJFA3  41770.45  4946.0           73         159835.710
# 1  CMP_JHHUE9  PROD_OE8YNJ  29900.93   570.0          510         165074.115
# 2  CMP_6SBOWN  PROD_4V8A08  22367.45  3546.0          265         124053.975
# 3  CMP_Q31QCU  PROD_A1Q6ZB  29957.54  2573.0          781         114789.652
# 4  CMP_AY0UTJ  PROD_F57N66  36277.19   818.0           79         138472.322
#
#     ROI  Customer_ID Subscription_Tier  Subscription Length  ...  \
# 0  1.94  CUST_1K7G39           Premium                    4  ...
# 1  0.76  CUST_0DWS6F           Premium                    4  ...
# 2  1.41  CUST_BR2GST             Basic                    9  ...
# 3  3.32  CUST_6TBY6K           Premium                   32  ...
# 4  3.53  CUST_XASI45          Standard                   29  ...
#
#   Discount Level  Units Sold    Bundle_ID Bundle Price  \
# 0           0.43          34  BNDL_29U6W5       433.80
# 1           0.28          97  BNDL_ULV60J       289.29
# 2           0.51         160  BNDL_0HY0EF       462.87
# 3           0.36         159  BNDL_AI09BC       334.16
# 4           0.20          52  BNDL_R03ITT       371.67
#
#    Customer Satisfaction Post Refund  Marketing Channels Conversion Rate  \
# 0                                  4            Facebook        1.475940
# 1                                  2              TikTok       89.473684
# 2                                  4              TikTok        7.473209
# 3                                  1              Google       30.353673
# 4                                  2            Facebook        9.657702
#
#    Budget per Conversion  Revenue Per Click  Revenue Per Unit
# 0             572.197945          32.316156       4701.050294
# 1              58.629275         289.603711       1701.795000
# 2              84.405472          34.984201        775.337344
# 3              38.357926          44.613157        721.947497
# 4             459.204937         169.281567       2662.929269
#
# [5 rows x 21 columns]

# %%
plot3_df = df.groupby('Marketing Channels')['Conversion Rate'].mean().sort_values(ascending=False).reset_index()
plot3_df
# Out:
#   Marketing Channels  Conversion Rate
# 0             TikTok        67.777914
# 1          Affiliate        60.190071
# 2             Google        58.962396
# 3           Facebook        56.840387

# %%
px.bar(data_frame= plot3_df, x='Marketing Channels', y= 'Conversion Rate',text_auto= True,title = 'Conversion Rate by Marketing',height = 520).update_xaxes(categoryorder = 'max descending').update_traces(texttemplate='%{y:.2f}%',textposition='outside')

# %%
plot4_df = df.groupby('Campaign_ID')['Revenue Generated'].sum().sort_values(ascending=False).reset_index().head(10)
plot4_df
# Out:
#   Campaign_ID  Revenue Generated
# 0  CMP_7FVX2Z         305392.743
# 1  CMP_BCB1BA         305303.700
# 2  CMP_XV0FRQ         305275.947
# 3  CMP_O1LPF1         305240.702
# 4  CMP_LUIMD2         305216.361
# 5  CMP_ROPOIR         305195.636
# 6  CMP_RSCIQV         305163.317
# 7  CMP_RZTOTU         305151.029
# 8  CMP_XDNU9C         305082.937
# 9  CMP_IC7ERM         304760.347

# %%
px.bar(data_frame= plot4_df, x='Campaign_ID', y= 'Revenue Generated',text_auto= True,title = 'Top 10 Campaigns by Revenue').update_xaxes(categoryorder = 'max descending')

# %%
plot5_df = df.groupby('Subscription_Tier')['Units Sold'].sum().sort_values(ascending=False).reset_index()
plot5_df
# Out:
#   Subscription_Tier  Units Sold
# 0             Basic      347725
# 1          Standard      330924
# 2           Premium      328247

# %%
px.pie(data_frame= plot5_df, names= 'Subscription_Tier',values = 'Units Sold', title='Units Sold by Subscription Tier').update_traces(textinfo='label+value')

# %%
## multivariat

plot6_df = df.groupby(['Subscription_Tier', 'Marketing Channels'])['Revenue Generated'].sum().round(2).reset_index()
plot6_df['Revenue Generated'] = plot6_df['Revenue Generated'].round().astype(int)
plot6_df
# Out:
#    Subscription_Tier Marketing Channels  Revenue Generated
# 0              Basic          Affiliate          124069918
# 1              Basic           Facebook           83417466
# 2              Basic             Google           82179520
# 3              Basic             TikTok          126189162
# 4            Premium          Affiliate          126535357
# 5            Premium           Facebook           84805794
# 6            Premium             Google           74369845
# 7            Premium             TikTok          113959271
# 8           Standard          Affiliate          127784244
# 9           Standard           Facebook           82483796
# 10          Standard             Google           78077262
# 11          Standard             TikTok          116372706

# %%
px.bar(data_frame= plot6_df, y= 'Marketing Channels', x= 'Revenue Generated',
       color= 'Subscription_Tier',
       barmode= 'group',
       text_auto= True)

# %%
plot7_df = df.groupby(['Subscription_Tier', 'Marketing Channels'])['Units Sold'].sum().reset_index()

plot7_df
# Out:
#    Subscription_Tier Marketing Channels  Units Sold
# 0              Basic          Affiliate       82458
# 1              Basic           Facebook       89959
# 2              Basic             Google       87244
# 3              Basic             TikTok       88064
# 4            Premium          Affiliate       82119
# 5            Premium           Facebook       87540
# 6            Premium             Google       73619
# 7            Premium             TikTok       84969
# 8           Standard          Affiliate       85611
# 9           Standard           Facebook       80464
# 10          Standard             Google       81302
# 11          Standard             TikTok       83547

# %%
px.bar(
    plot7_df,
    x='Subscription_Tier',
    y='Units Sold',
    color='Marketing Channels',
    barmode='group',
    text_auto=True,
    title='Units Sold by Marketing Channel and Subscription Tier'
)

# %%
# %%writefile  Product_Performance_MidProject.py

import streamlit as st
import numpy as np
import pandas as pd
import plotly.express as px

st.set_page_config(page_title="Marketing Campaign Analysis",page_icon="📊",layout="wide")
html_title = """<h1 style = "color:white;text-align:center;"> Product Performance </h1>"""
st.markdown(html_title, unsafe_allow_html=True)
df = pd.read_excel('Cleaned Product Performance.xlsx', index_col= 0)
page = st.sidebar.radio('pages',['DataFrame and Overview','Detailed Analysis','Dashboard'])

if page == 'DataFrame and Overview':
    st.header('📊 Marketing Campaign Analysis')
    with st.expander("Data and business understanding"):
        st.write("This dataset provides a comprehensive look at the intersection of marketing expenditure and sales performance for company named ELSA that leveraging multi-channel advertising (Facebook, Google, TikTok, Affiliate) and data-driven promotional campaigns (Flash Sales, Product Bundles) to optimize Customer Acquisition Cost (CAC) and Lifetime Value (LTV).")
        
    st.dataframe(df)

elif page == 'Detailed Analysis':
    st.header('📊 Exploratory Data Analysis')
    analysis_type = st.tabs(["Univariate","Bivariate","Multivariate"])

    with analysis_type[0]:
        st.subheader("Univariate Analysis")
        st.markdown("Explore the distribution and characteristics of individual variables.")
        col1, col2, col3, col4 = st.columns(4)
        with col1:
            st.metric("Total Records", f"{len(df):,}")
        with col2:
            st.metric(
                "Total Revenue",
                f"{df['Revenue Generated'].sum():,.0f}"
            )
        with col3:
            st.metric(
                "Total Units Sold",
                f"{df['Units Sold'].sum():,.0f}"
            )
        with col4:
            st.metric(
                "Marketing Channels",
                df['Marketing Channels'].nunique()
            )
        with st.expander("💡 What does the data tell us?"):

            st.markdown("""
            ### Univariate Analysis
    
            Univariate analysis examines one variable at a time.
    
            It helps us understand:
            - The distribution of the data
            - The overall scale of each variable
    
            **Business purpose:**  
            Understanding individual variables gives us a foundation
            before investigating relationships between variables.
            """)
        st.divider()
        st.subheader("📈 Variable Distributions")
        targcol = ['Marketing Channels','Subscription_Tier','Revenue Generated', 'Budget', 'Clicks','Conversions', 'ROI', 'Subscription Length','Discount Level','Units Sold','Bundle Price']
        for col in targcol:
            fig = px.histogram(data_frame = df, x = col, text_auto = True,nbins=40).update_xaxes(categoryorder = 'max descending')
            st.plotly_chart(fig, use_container_width = True)
    with analysis_type[1]:
        st.subheader("🔗 Bivariate Analysis")

        st.markdown(
            "Explore relationships and comparisons between two variables."
        )
        with st.expander("💡 What does the data tell us?"):
    
            st.markdown("""
            ### Bivariate Analysis
    
            Bivariate analysis investigates the relationship between
            two variables.
    
            For example:
    
            **Subscription_Tier → Units Sold**
    
            This helps us determine which tier with higher units sold.
    
            **Marketing Channel → ROI**
    
            This allows us to compare the efficiency of different
            marketing channels.
    
            **Business purpose:**  
            Identify relationships, differences, and potential patterns
            that can support marketing decisions.
            """)
    
        st.divider()
        col1, col2 = st.columns(2)
    
        with col1:
    
             roi_df = (
                df.groupby("Marketing Channels")["ROI"]
                .mean()
                .sort_values(ascending=False)
                .reset_index())
            
             fig2 = px.bar(
                roi_df,
                x="Marketing Channels",
                y="ROI",
                title="Average ROI by Marketing Channel",
                text_auto=".2f",height = 500
             ).update_traces(textposition='outside')
             st.plotly_chart(
                        fig2,
                        use_container_width=True
                    )
        with col2:
            plot4_df = df.groupby('Subscription_Tier')['Revenue Generated'].sum().sort_values(ascending=False).reset_index()
            plot4_df['Revenue Generated'] = plot4_df['Revenue Generated'].round().astype(int)
            fig3 = px.bar(data_frame= plot4_df, x='Subscription_Tier', y= 'Revenue Generated',text_auto= True,title = 'Revenue Generated By Tiers',height = 500).update_xaxes(categoryorder = 'max descending').update_traces(textposition='outside')
            st.plotly_chart(
                        fig3,
                        use_container_width=True
                    )
    with analysis_type[2]:
        st.subheader("🎯 Multivariate Analysis")

        st.markdown(
            "Analyze multiple variables together to uncover deeper business insights."
        )

        with st.expander("💡 What does the data tell us?"):

            st.markdown("""
            ### Analysis Description
    
            This analysis examines three variables simultaneously:
    
            - **Marketing Channel**
            - **Subscription Tier**
            - **Units Sold**
    
            The goal is to determine whether the most effective marketing
            channel changes depending on the subscription tier.
    
            ### Business Insight
             The results can help the company avoid using a
            **one-size-fits-all marketing strategy**.
    
            If different subscription tiers perform better through
            different channels, marketing resources can be allocated
            according to the behavior of each customer segment.
    
            ### 💼 Business Application
    
            This analysis can support:
    
            - Marketing budget allocation
            - Customer segmentation
            - Campaign targeting
            - Channel optimization
            - Sales strategy
            """)
        st.divider()
       
        top_channels = (
        df.loc[
            df.groupby("Subscription_Tier")["Clicks"]
            .idxmax()
        ]
        .reset_index(drop=True)
      )
        st.markdown("### 🏆 Best Marketing Channel by Subscription Tier")
    
        cols = st.columns(len(top_channels))
    
        for col, (_, row) in zip(cols, top_channels.iterrows()):
             with col:

                st.metric(
                    label=row["Subscription_Tier"],
                    value=row["Marketing Channels"],
                    delta=f"{row['Clicks']:,} Clicks"
                )
        st.divider()
        st.markdown(
        "### 🎯 Marketing Channel × Subscription Tier × Units Sold"
         )
        plot7_df = df.groupby(['Subscription_Tier', 'Marketing Channels'])['Units Sold'].sum().reset_index()
        fig4 = px.bar(
            plot7_df,
            x='Subscription_Tier',
            y='Units Sold',
            color='Marketing Channels',
            barmode='group',
            text_auto=True,
            title='Units Sold by Marketing Channel and Subscription Tier'
           )
        st.plotly_chart(
                        fig4,
                        use_container_width=True
                    )

elif page == 'Dashboard':
    st.caption(
        "A high-level overview of marketing, sales, and campaign performance."
    )
    total_revenue = df["Revenue Generated"].sum()
    revenue_per_unit = df["Revenue Per Unit"].mean()
    revenue_per_click = df["Revenue Per Click"].mean()
    budget_per_conversion = df["Budget per Conversion"].mean()
    total_units = df["Units Sold"].sum()
    total_conversions = df["Conversions"].sum()
    total_clicks = df["Clicks"].sum()
    overall_conversion_rate = (total_conversions / total_clicks * 100)
    col1, col2, col3, col4 = st.columns(4)

    with col1:
        st.metric(
            "💰 Total Revenue",
            f"{total_revenue:,.0f}"
        )
    with col2:
        st.metric(
            "📦 Revenue Per Unit",
            f"{revenue_per_unit:,.2f}"
        )

    with col3:
        st.metric(
            "🖱 Revenue Per Click",
            f"{revenue_per_click:,.2f}"
        )
    with col4:
        st.metric(
            "🎯 Budget Per Conversion",
            f"{budget_per_conversion:,.2f}"
        )

    st.divider()
    col1, col2 = st.columns(2)
    with col1:
        month_sorted = df.sort_values('Subscription Length')
        plot2_df = month_sorted.groupby('Subscription Length')['Customer_ID'].count().reset_index()
        fig5 = px.line(data_frame= plot2_df, x= 'Subscription Length', y= 'Customer_ID',
        labels= {'Subscription Length' : 'Month', 'Customer_ID' : 'Customer Count'},
        title= 'Total number of customers per month subscriptions',
        text= 'Customer_ID',
        line_shape= 'spline').update_traces(textposition= 'top center')
        st.plotly_chart(
                        fig5,
                        use_container_width=True
                    )
    with col2:

        units_tier = (
            df.groupby("Subscription_Tier")["Units Sold"]
            .sum()
            .sort_values(ascending=False)
            .reset_index()
        )
        fig6 = px.bar(
            units_tier,
            x="Subscription_Tier",
            y="Units Sold",
            text_auto=True,
            title=" Units Sold by Subscription Tier"
        ).update_layout(
            xaxis_title="Subscription Tier",
            yaxis_title="Units Sold",
            showlegend=False
        )
        st.plotly_chart(
            fig6,
            use_container_width=True
        )
    col1, col2 = st.columns(2)
    with col1:
         roi_channel = (
            df.groupby("Marketing Channels")["ROI"]
            .mean()
            .sort_values(ascending=False)
            .reset_index())
         fig7 = px.bar(
            roi_channel,
            x="Marketing Channels",
            y="ROI",
            text_auto=".2f",
            title="Average ROI by Marketing Channel",height= 520
         ).update_layout(
            xaxis_title="Marketing Channels",
            yaxis_title="Average ROI",
            showlegend=False).update_traces(textposition='outside')
         st.plotly_chart(fig7,use_container_width=True)
         
    with col2:
        plot3_df = df.groupby('Marketing Channels')['Conversion Rate'].mean().sort_values(ascending=False).reset_index()
        fig8 = px.bar(data_frame= plot3_df, x='Marketing Channels', y= 'Conversion Rate',text_auto= True,title = 'Conversion Rate by Marketing',height= 520).update_xaxes(categoryorder = 'max descending').update_traces(texttemplate='%{y:.2f}%',textposition='outside')
        st.plotly_chart(fig8,use_container_width=True)

    st.divider()
    
    st.subheader("💡 Key Dashboard Insights")
    
    revenue_channel = (
        df.groupby("Marketing Channels")["Revenue Generated"]
        .sum()
        .sort_values(ascending=False)
        .reset_index()
    )
    
    top_revenue_channel = revenue_channel.iloc[0]["Marketing Channels"]
    top_revenue_value = revenue_channel.iloc[0]["Revenue Generated"]
    
    
    units_tier = (
        df.groupby("Subscription_Tier")["Units Sold"]
        .sum()
        .sort_values(ascending=False)
        .reset_index()
    )
    
    top_units_tier = units_tier.iloc[0]["Subscription_Tier"]
    top_units_value = units_tier.iloc[0]["Units Sold"]
    
    
    roi_channel = (
        df.groupby("Marketing Channels")["ROI"]
        .mean()
        .sort_values(ascending=False)
        .reset_index()
    )
    
    top_roi_channel = roi_channel.iloc[0]["Marketing Channels"]
    top_roi_value = roi_channel.iloc[0]["ROI"]
    
    conversion_rate_channel = (
        df.groupby("Marketing Channels")
        .agg({
            "Conversions": "sum",
            "Clicks": "sum"
        })
        .reset_index()
    )
    
    conversion_rate_channel["Conversion Rate"] = (
        conversion_rate_channel["Conversions"]
        / conversion_rate_channel["Clicks"]
        * 100
    )
    
    conversion_rate_channel = (
        conversion_rate_channel
        .sort_values("Conversion Rate", ascending=False)
    )
    
    top_conversion_channel = (
        conversion_rate_channel.iloc[0]["Marketing Channels"]
    )
    
    top_conversion_rate = (
        conversion_rate_channel.iloc[0]["Conversion Rate"]
    )
    
    
    budget_revenue_corr = (
        df["Budget"]
        .corr(df["Revenue Generated"])
    )
    
    
    col1, col2 = st.columns(2)
    
    with col1:
    
        st.info(
            f"""
            ### 📈 ROI Performance
    
            **{top_roi_channel}** recorded the highest average
            ROI at **{top_roi_value:.2f}**.
    
            ROI measures the return generated relative to the
            investment associated with the campaign.
            """
        )
    
    
    with col2:
    
        st.info(
            f"""
            ### 🎯 Conversion Performance
    
            **{top_conversion_channel}** achieved the highest
            overall conversion rate at **{top_conversion_rate:.2f}%**.
    
            This means this channel converted clicks into
            conversions at the highest rate among the channels.
            """
        )
    
    st.markdown("### 📊 Overall Performance")
    
    col1, col2, col3, col4 = st.columns(4)
    
    with col1:
        st.metric(
            "Total Revenue",
            f"{total_revenue:,.0f}"
        )
    
    with col2:
        st.metric(
            "Total Units Sold",
            f"{total_units:,.0f}"
        )
    
    with col3:
        st.metric(
            "Total Conversions",
            f"{total_conversions:,.0f}"
        )
    
    with col4:
        st.metric(
            "Overall Conversion Rate",
            f"{overall_conversion_rate:.2f}%"
        )

    
    st.markdown("### 💵 Budget & Revenue Relationship")
    
    st.write(
        f"""
        The correlation between **Budget** and **Revenue** is
        **{budget_revenue_corr:.2f}**.
    
        This measures the strength and direction of the linear
        relationship between campaign budget and generated revenue.
        """
    )
# Out:
# Overwriting Product_Performance_MidProject.py

# %%
! streamlit run Product_Performance_MidProject.py
# Out:
# ^C

# %%
# !pipreqs ./ --encoding=utf-8
# Out:
# WARNING: Import named "numpy" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "numpy" was resolved to "numpy:2.5.3" package (https://pypi.org/project/numpy/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "pandas" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "pandas" was resolved to "pandas:3.0.6" package (https://pypi.org/project/pandas/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# INFO: Successfully saved requirements file in ./requirements.txt
